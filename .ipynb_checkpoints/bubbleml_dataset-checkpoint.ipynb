# %%
import torch
import h5py
import os
import glob
import numpy as np
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

class PoolBoilingDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.file_paths = []
        self.frame_counts = []
        self.cumulative_indices = [0]
        
        # sorted to ensure consistent ordering
        search_path = os.path.join(root_dir, "PoolBoiling-*", "*.hdf5")
        self.file_paths = sorted(glob.glob(search_path))
        
        print(f"Indexing {len(self.file_paths)} files...")
        total_frames = 0
        for p in self.file_paths:
            with h5py.File(p, 'r') as f:
                # We assume temperature and dfun have the same length
                count = f["temperature"].shape[0]
                self.frame_counts.append(count)
                total_frames += count
                self.cumulative_indices.append(total_frames)
        
        print(f"Total frames indexed: {total_frames}")

    def __len__(self):
        return self.cumulative_indices[-1]

    def __getitem__(self, idx):
        # Find which file the global index belongs to
        file_idx = 0
        for i in range(len(self.cumulative_indices) - 1):
            if idx < self.cumulative_indices[i+1]:
                file_idx = i
                break
        
        # Calculate local frame index within that file
        local_idx = idx - self.cumulative_indices[file_idx]
        file_path = self.file_paths[file_idx]
        
        with h5py.File(file_path, 'r') as f:
            # Load both channels
            temp = f["temperature"][local_idx]
            dfun = f["dfun"][local_idx]
            
            # Stack along channel axis (axis 0)
            # Resulting shape: (2, H, W)
            # Channel 0: Temperature
            # Channel 1: dfun
            data = np.stack([temp, dfun], axis=0).astype('float32')
            
        sample = torch.from_numpy(data)

        if torch.isnan(sample).any():
            print(f"NaN detected in {file_path} at index {local_idx}")
        
        if self.transform:
            sample = self.transform(sample)
            
        return sample

# %%
dataset = PoolBoilingDataset(root_dir='./bubbleml-ds')

dataloader = DataLoader(
    dataset, 
    batch_size=32, 
    shuffle=True, 
    num_workers=2
)

print(f"Number of batches: {len(dataloader)}")
for batch in dataloader:
    print(f"Batch shape: {batch.shape}")  # Expected: torch.Size([32, 2, 64, 64])
    print(f"Channel 0 (Temp) shape: {batch[:, 0, ...].shape}")
    print(f"Channel 1 (Dfun) shape: {batch[:, 1, ...].shape}")
    break

def get_stats(loader):
    n_pixels = 0
    
    # Channel 0 (Temp) accumulators
    temp_sum = 0.0
    temp_sq_sum = 0.0
    
    # Channel 1 (Dfun) accumulators
    dfun_sum = 0.0
    dfun_sq_sum = 0.0
    
    print("Calculating statistics...")
    for data in tqdm(loader):
        # data: [B, 2, H, W]
        b, c, h, w = data.shape
        # Total pixels in this batch per channel
        num_el = b * h * w
        n_pixels += num_el
        
        # Channel 0: Temperature
        temp_batch = data[:, 0, :, :]
        temp_sum += torch.sum(temp_batch).item()
        temp_sq_sum += torch.sum(temp_batch ** 2).item()
        
        # Channel 1: dfun
        dfun_batch = data[:, 1, :, :]
        dfun_sum += torch.sum(dfun_batch).item()
        dfun_sq_sum += torch.sum(dfun_batch ** 2).item()
        
    # Calculate global stats
    # Mean = E[X]
    temp_mean = temp_sum / n_pixels
    dfun_mean = dfun_sum / n_pixels
    
    # Std = sqrt(E[X^2] - (E[X])^2)
    temp_std = (temp_sq_sum / n_pixels - temp_mean ** 2) ** 0.5
    dfun_std = (dfun_sq_sum / n_pixels - dfun_mean ** 2) ** 0.5
        
    return (temp_mean, temp_std), (dfun_mean, dfun_std)

# Use a larger batch size for stats calculation speed
loader = DataLoader(dataset, batch_size=256, num_workers=4)
(t_means, t_stds), (d_means, d_stds) = get_stats(loader)
# Out:
# Indexing 124 files...
# Total frames indexed: 248124
# Number of batches: 7754
# Batch shape: torch.Size([32, 2, 64, 64])
# Channel 0 (Temp) shape: torch.Size([32, 64, 64])
# Channel 1 (Dfun) shape: torch.Size([32, 64, 64])
# /home/jovyan/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Calculating statistics...
#   1%|          | 8/970 [05:06<10:13:26, 38.26s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 59
#      57 # Use a larger batch size for stats calculation speed
#      58 loader = DataLoader(dataset, batch_size=256, num_workers=4)
# ---> 59 (t_means, t_stds), (d_means, d_stds) = get_stats(loader)
#
# Cell In[2], line 29, in get_stats(loader)
#      26 dfun_sq_sum = 0.0
#      28 print("Calculating statistics...")
# ---> 29 for data in tqdm(loader):
#      30     # data: [B, 2, H, W]
#      31     b, c, h, w = data.shape
#      32     # Total pixels in this batch per channel
#
# File /opt/apps/python/3.10.2/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1316, in _MultiProcessingDataLoaderIter._next_data(self)
#    1313     return self._process_data(data)
#    1315 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316 idx, data = self._get_data()
#    1317 self._tasks_outstanding -= 1
#    1318 if self._dataset_kind == _DatasetKind.Iterable:
#    1319     # Check for _IterableDatasetStopIteration
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1282, in _MultiProcessingDataLoaderIter._get_data(self)
#    1278     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1279     # need to call `.task_done()` because we don't use `.join()`.
#    1280 else:
#    1281     while True:
# -> 1282         success, data = self._try_get_data()
#    1283         if success:
#    1284             return data
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1120, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1107 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1108     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1109     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1117     # Returns a 2-tuple:
#    1118     #   (bool: whether successfully get data, any: data if successful else None)
#    1119     try:
# -> 1120         data = self._data_queue.get(timeout=timeout)
#    1121         return (True, data)
#    1122     except Exception as e:
#    1123         # At timeout and error, we manually check whether any worker has
#    1124         # failed. Note that this is the only mechanism for Windows to detect
#    1125         # worker failures.
#
# File /opt/apps/python/3.10.2/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File /opt/apps/python/3.10.2/lib/python3.10/multiprocessing/connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File /opt/apps/python/3.10.2/lib/python3.10/multiprocessing/connection.py:429, in Connection._poll(self, timeout)
#     428 def _poll(self, timeout):
# --> 429     r = wait([self], timeout)
#     430     return bool(r)
#
# File /opt/apps/python/3.10.2/lib/python3.10/multiprocessing/connection.py:936, in wait(object_list, timeout)
#     933     deadline = time.monotonic() + timeout
#     935 while True:
# --> 936     ready = selector.select(timeout)
#     937     if ready:
#     938         return [key.fileobj for (key, events) in ready]
#
# File /opt/apps/python/3.10.2/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
print(f"Avg Temp Mean: {np.mean(t_means):.4f}")
print(f"Avg Temp Std:  {np.mean(t_stds):.4f}")
print(f"Avg Dfun Mean: {np.mean(d_means):.4f}")
print(f"Avg Dfun Std:  {np.mean(d_stds):.4f}")
